# %%
from time import sleep

# %%
from random import random
random_list = []
for i in range(10000):
    random_list.append(random())

# %%
print(random_list)
# Out:
# [0.8732266418478314, 0.5683453337560163, 0.6829290747844361, 0.5330922235333492, 0.46311601754507237, 0.15312378191340736, 0.1855583777038764, 0.31593248812817276, 0.5204728004481612, 0.6444419255899666, 0.6798571381963058, 0.7206586141120602, 0.5230566946091566, 0.3419964911659209, 0.20781474941860845, 0.8171386356729342, 0.6710972123563277, 0.4151565606695403, 0.5593396973597016, 0.6880550267080296, 0.2895322734567879, 0.06534935037331313, 0.6550508915669492, 0.1866614383422266, 0.04618017231186866, 0.48287466945379365, 0.36520671266385984, 0.44376309628477584, 0.1522878322875606, 0.09040545855871407, 0.3473229530896461, 0.19429245034628473, 0.3283033492921914, 0.5581920865719167, 0.7297379266759846, 0.7552742456004463, 0.2966738727414596, 0.5476730624160857, 0.8785391797138015, 0.3229667931278021, 0.8635532376070758, 0.6569702823099554, 0.8953842237011588, 0.5409097541632537, 0.8547673709789809, 0.8144344276733827, 0.6329600382771127, 0.9029429677483771, 0.9094803479250428, 0.6159
# ...

# %%
from tqdm import tqdm
for i in tqdm(random_list[1:]):
    print(i)
    sleep(random())
# Out:
#   0%|          | 0/9999 [00:00<?, ?it/s]
# 0.5683453337560163
# 0.6829290747844361
#   0%|          | 2/9999 [00:00<25:51,  6.44it/s]
# 0.5330922235333492
#   0%|          | 3/9999 [00:00<54:33,  3.05it/s]
# 0.46311601754507237
#   0%|          | 4/9999 [00:01<1:05:30,  2.54it/s]
# 0.15312378191340736
#   0%|          | 5/9999 [00:02<1:25:19,  1.95it/s]
# 0.1855583777038764
#   0%|          | 6/9999 [00:02<1:22:32,  2.02it/s]
# 0.31593248812817276
#   0%|          | 7/9999 [00:03<1:23:31,  1.99it/s]
# 0.5204728004481612
#   0%|          | 8/9999 [00:03<1:12:18,  2.30it/s]
# 0.6444419255899666
#   0%|          | 9/9999 [00:04<1:31:51,  1.81it/s]
# 0.6798571381963058
#   0%|          | 10/9999 [00:04<1:25:37,  1.94it/s]
# 0.7206586141120602
#   0%|          | 11/9999 [00:05<1:45:42,  1.57it/s]
# 0.5230566946091566
#   0%|          | 12/9999 [00:06<1:41:36,  1.64it/s]
# 0.3419964911659209
#   0%|          | 13/9999 [00:07<1:59:15,  1.40it/s]
# 0.20781474941860845
# ...
